# %% [markdown]
# # STEP 2: Wrangle Raster Data
#
# # STEP 0: Set up
#
# To get started on this notebook, you’ll need to restore any variables
# from previous notebooks to your workspace. To save time and memory, make
# sure to specify which variables you want to load.

# %%
# %store -r

# %% [markdown]
# You will also need to import any libraries you are using in this
# notebook, since they won’t carry over from the previous notebook:

# %%
# Import libraries
#from glob import glob

import earthpy
import rioxarray as rxr  # to work with raster data
import xarray as xr # to work with data arrays
import pandas as pd # work with tabular data and dates

# %% [markdown]
# ## Load in NDVI data
#
# Now you need to load all the downloaded files into Python. Let’s start
# by getting all the file names. You will also need to extract the date
# from the filename. Check out [the lesson on getting information from
# filenames in the
# textbook](https://www.earthdatascience.org/courses/intro-to-earth-data-science/write-efficient-python-code/loops/data-workflows-with-loops/).
#
# In this lesson, you will use the `glob.glob()` function in Python to
# find all files that match a **pattern** formed with the **wildcard**
# character `*`. The wildcard can represent any string of alphanumberic
# characters. For example, the pattern `'file_*.tif'` will match the files
# `'file_1.tif'`, `'file_2.tiv'`, or even
# `'file_qeoiurghtfoqaegbn34pf.tif'`… but it will not match
# `'something-else.csv'` or even `'something-else.tif'`.
#
# In this notebook, we’ll use the `.rglob()`, or **recursive** glob method
# of the Path object instead. It works similarly, but you’ll notice that
# we have to convert the results to a list with the `list()` function.
#
# > **GOTCHA ALERT!**
# >
# > `glob` doesn’t necessarily find files in the order you would expect.
# > Make sure to **sort** your file names like it says in the textbook.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-respond"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Reflect and Respond</div></div><div class="callout-body-container callout-body"><p>Take a look at the file names for the NDVI files. What do you notice
# is the same for all the files? Keep in mind that you only want the NDVI
# files, not the Quality files (which will flag potential incorrect
# measurements).</p></div></div>

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>Create a <strong>pattern</strong> for the files you want to import.
# Your pattern should include the parts of the file names that are the
# same for all files, and replace the rest with the <code>*</code>
# character. Make sure to match the NDVI files, but not the Quality
# files!</li>
# <li>Replace <code>ndvi-pattern</code> with your pattern</li>
# <li>Run the code and make sure that you are getting all the files you
# want and none of the files you don’t!</li>
# </ol></div></div>

# %%
# Get a sorted list of NDVI tif file paths
ndvi_paths = sorted(list(project.project_dir.rglob('*NDVI*.tif')))

# Display the first and last three files paths to check the pattern
ndvi_paths[:3], ndvi_paths[-3:]
# Out:
# ([PosixPath('/workspaces/data/gila-vegetation-data/gila-river-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2001145000000_aid0001.tif'),
#   PosixPath('/workspaces/data/gila-vegetation-data/gila-river-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2001161000000_aid0001.tif'),
#   PosixPath('/workspaces/data/gila-vegetation-data/gila-river-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2001177000000_aid0001.tif')],
#  [PosixPath('/workspaces/data/gila-vegetation-data/gila-river-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2022209000000_aid0001.tif'),
#   PosixPath('/workspaces/data/gila-vegetation-data/gila-river-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2022225000000_aid0001.tif'),
#   PosixPath('/workspaces/data/gila-vegetation-data/gila-river-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2022241000000_aid0001.tif')])

# %% [markdown]
# ## Repeating tasks in Python
#
# Now you should have a few dozen files! For each file, you need to:
#
# -   Load the file in using the `rioxarray` library
# -   Get the date from the file name
# -   Add the date as a dimension coordinate
# -   Give your data variable a name
#
# You don’t want to write out the code for each file! That’s a recipe for
# copy pasta. Luckily, Python has tools for doing similar tasks
# repeatedly. In this case, you’ll use one called a `for` loop.
#
# There’s some code below that uses a `for` loop in what is called an
# **accumulation pattern** to process each file. That means that you will
# save the results of your processing to a list each time you process the
# files, and then merge all the arrays in the list.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ul>
# <li>Look at the file names. How many characters from the end is the
# date? <code>doy_start</code> and <code>doy_end</code> are used to
# extract the day of the year (doy) from the file name. You will need to
# count characters from the end and change the values to get the right
# part of the file name. HINT: the index -1 in Python means the last
# value, -2 second-to-last, and so on.</li>
# <li>Replace any required variable names with your chosen variable
# names</li>
# </ul></div></div>

# %%
import matplotlib.pyplot as plt

# %%
# Plot 1st and last .tif image
rxr.open_rasterio(ndvi_paths[0], mask_and_scale=True).squeeze().plot(cmap=plt.cm.PiYG)

# %%
rxr.open_rasterio(ndvi_paths[-1], mask_and_scale=True).squeeze().plot(cmap=plt.cm.PiYG)

# %%
# Load the rasters
ndvi_recent = rxr.open_rasterio(ndvi_paths[-1], mask_and_scale=True).squeeze()
ndvi_early = rxr.open_rasterio(ndvi_paths[0], mask_and_scale=True).squeeze()

# Create side-by-side subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Plot each NDVI raster on its own axis
ndvi_early.plot(ax=axes[0], cmap=plt.cm.PiYG, vmin=-1, vmax=1)
axes[0].set_title("NDVI - Earliest")

ndvi_recent.plot(ax=axes[1], cmap=plt.cm.PiYG, vmin=-1, vmax=1)
axes[1].set_title("NDVI - Most Recent")

# Improve layout
plt.tight_layout()
plt.show()

# %%
# Load NDVI rasters
ndvi_recent = rxr.open_rasterio(ndvi_paths[-1], mask_and_scale=True).squeeze()
ndvi_early = rxr.open_rasterio(ndvi_paths[0], mask_and_scale=True).squeeze()

# Create side-by-side subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot earliest NDVI
ndvi_early.plot(ax=axes[0], cmap=plt.cm.PiYG, vmin=-1, vmax=1)
gric_boundary.plot(ax=axes[0], edgecolor='black', facecolor='none', linewidth=1)
axes[0].set_title("NDVI - Earliest")

# Plot most recent NDVI
ndvi_recent.plot(ax=axes[1], cmap=plt.cm.PiYG, vmin=-1, vmax=1)
gric_boundary.plot(ax=axes[1], edgecolor='black', facecolor='none', linewidth=1)
axes[1].set_title("NDVI - Most Recent")

# Improve layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# Plot 1st and last .tif image
rxr.open_rasterio(ndvi_paths[-1], mask_and_scale=True).squeeze().plot()

gric_boundary.plot(ax=plt.gca(), edgecolor='black', color='none')

# %%
doy_start = -25
doy_end = -18

# Loop through each NDVI image
ndvi_das = []
for ndvi_path in ndvi_paths:
    # Get date from file name
    date_string = ndvi_path.name[doy_start:doy_end]
    #print(date_string)
    date = pd.to_datetime(date_string, format='%Y%j')
    #print(date)

    # Open dataset
    da = rxr.open_rasterio(ndvi_path, mask_and_scale=True).squeeze()
    #display(da)

    # Add date dimension and clean up metadata
    da = da.assign_coords({'date': date})  # assign coordinate
    da = da.expand_dims({'date': 1})   # turn into dimension
    da.name = 'NDVI'  # we have to give it a name (for nice plotting?)

    # Prepare for concatenation
    ndvi_das.append(da) 

    

len(ndvi_das)

# %%
# Look at the data
ndvi_das
# Out:
# [<xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.8282    , 0.6146    , 0.3796    , ..., 0.1542    ,
#           0.1542    , 0.1774    ],
#          [0.52349997, 0.32029998, 0.46359998, ..., 0.145     ,
#           0.145     , 0.145     ],
#          [0.52349997, 0.38509998, 0.4567    , ..., 0.0962    ,
#           0.058     , 0.0641    ],
#          ...,
#          [0.13759999, 0.13759999, 0.1283    , ..., 0.1489    ,
#           0.1489    , 0.1568    ],
#          [0.1299    , 0.1299    , 0.12379999, ..., 0.1831    ,
#           0.1831    , 0.23169999],
#          [0.1347    , 0.1309    , 0.1329    , ..., 0.15709999,
#           0.2384    , 0.2452    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5146    , 0.42249998, 0.3706    , ..., 0.1656    ,
#           0.1656    , 0.1656    ],
#          [0.3543    , 0.4138    , 0.3706    , ..., 0.1275    ,
#           0.1275    , 0.0968    ],
#          [0.48029998, 0.3543    , 0.3687    , ..., 0.075     ,
#           0.075     , 0.0968    ],
#          ...,
#          [0.1308    , 0.1308    , 0.1234    , ..., 0.1592    ,
#           0.1592    , 0.153     ],
#          [0.127     , 0.127     , 0.1164    , ..., 0.1689    ,
#           0.1689    , 0.23349999],
#          [0.1258    , 0.1179    , 0.1179    , ..., 0.2157    ,
#           0.2549    , 0.19649999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.63519996, 0.4851    , 0.463     , ..., 0.1628    ,
#           0.1628    , 0.1591    ],
#          [0.7064    , 0.5079    , 0.3888    , ..., 0.083     ,
#           0.083     , 0.16      ],
#          [0.50839996, 0.4632    , 0.5103    , ..., 0.1243    ,
#           0.1243    , 0.083     ],
#          ...,
#          [0.1282    , 0.1282    , 0.127     , ..., 0.15439999,
#           0.15439999, 0.1608    ],
#          [0.1266    , 0.1266    , 0.12289999, ..., 0.19909999,
#           0.19909999, 0.2705    ],
#          [0.13319999, 0.1205    , 0.1287    , ..., 0.2753    ,
#           0.2942    , 0.2705    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6785    , 0.4888    , 0.55509996, ..., 0.13409999,
#           0.13409999, 0.17909999],
#          [0.736     , 0.479     , 0.5006    , ..., 0.1391    ,
#           0.1391    , 0.1282    ],
#          [0.5469    , 0.494     , 0.5554    , ..., 0.0874    ,
#           0.0874    , 0.0593    ],
#          ...,
#          [0.1314    , 0.1314    , 0.12969999, ..., 0.15609999,
#           0.15609999, 0.1708    ],
#          [0.1314    , 0.1314    , 0.1227    , ..., 0.2351    ,
#           0.2351    , 0.2447    ],
#          [0.1488    , 0.12629999, 0.1217    , ..., 0.2078    ,
#           0.3374    , 0.24329999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-07-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.537     , 0.3586    , 0.4341    , ..., 0.1533    ,
#           0.1533    , 0.1598    ],
#          [0.537     , 0.49699998, 0.4367    , ..., 0.1533    ,
#           0.1533    , 0.1598    ],
#          [0.49969998, 0.4612    , 0.4741    , ..., 0.0913    ,
#           0.0913    , 0.07539999],
#          ...,
#          [0.134     , 0.134     , 0.133     , ..., 0.2047    ,
#           0.2047    , 0.1592    ],
#          [0.12629999, 0.12629999, 0.1312    , ..., 0.1806    ,
#           0.1806    , 0.2218    ],
#          [0.146     , 0.13      , 0.1241    , ..., 0.20539999,
#           0.2793    , 0.31399998]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-07-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7511    , 0.6297    , 0.48209998, ..., 0.1507    ,
#           0.1507    , 0.1686    ],
#          [0.7511    , 0.6297    , 0.5035    , ..., 0.10879999,
#           0.10879999, 0.0914    ],
#          [0.6051    , 0.5087    , 0.4317    , ..., 0.1134    ,
#           0.0756    , 0.0479    ],
#          ...,
#          [0.1442    , 0.1442    , 0.132     , ..., 0.18509999,
#           0.18509999, 0.1743    ],
#          [0.1373    , 0.1373    , 0.12419999, ..., 0.19489999,
#           0.19489999, 0.26479998],
#          [0.141     , 0.1273    , 0.1383    , ..., 0.2464    ,
#           0.2634    , 0.26479998]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-08-13
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.49339998, 0.4224    , 0.4569    , ..., 0.1452    ,
#           0.1452    , 0.1598    ],
#          [0.5139    , 0.3566    , 0.4569    , ..., 0.1208    ,
#           0.1208    , 0.10969999],
#          [0.53499997, 0.3566    , 0.4481    , ..., 0.0931    ,
#           0.048     , 0.048     ],
#          ...,
#          [0.1357    , 0.1357    , 0.12419999, ..., 0.1733    ,
#           0.1733    , 0.17889999],
#          [0.1295    , 0.1295    , 0.1291    , ..., 0.2602    ,
#           0.2602    , 0.2814    ],
#          [0.1349    , 0.12469999, 0.1313    , ..., 0.2426    ,
#           0.3143    , 0.3154    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-08-29
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.70489997, 0.39569998, 0.3893    , ..., 0.12539999,
#           0.12539999, 0.1437    ],
#          [0.43069997, 0.31399998, 0.3565    , ..., 0.1173    ,
#           0.1173    , 0.11449999],
#          [0.4719    , 0.3876    , 0.3209    , ..., 0.09339999,
#           0.09339999, 0.0699    ],
#          ...,
#          [0.1347    , 0.1347    , 0.12879999, ..., 0.1329    ,
#           0.1329    , 0.1486    ],
#          [0.1284    , 0.1284    , 0.1208    , ..., 0.1837    ,
#           0.1837    , 0.1979    ],
#          [0.1264    , 0.1213    , 0.1363    , ..., 0.16849999,
#           0.225     , 0.2078    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7669    , 0.59679997, 0.4143    , ..., 0.1201    ,
#           0.1201    , 0.13059999],
#          [0.5114    , 0.3013    , 0.3216    , ..., 0.0947    ,
#           0.0947    , 0.13059999],
#          [0.43699998, 0.32729998, 0.29569998, ..., 0.09559999,
#           0.0947    , 0.0733    ],
#          ...,
#          [0.1278    , 0.1278    , 0.1345    , ..., 0.1443    ,
#           0.1443    , 0.14019999],
#          [0.1223    , 0.1223    , 0.12159999, ..., 0.21319999,
#           0.21319999, 0.1944    ],
#          [0.1405    , 0.1218    , 0.1304    , ..., 0.2031    ,
#           0.22119999, 0.21319999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.4464    , 0.3574    , 0.3691    , ..., 0.13859999,
#           0.13859999, 0.1414    ],
#          [0.49429998, 0.3788    , 0.3272    , ..., 0.1152    ,
#           0.1152    , 0.1118    ],
#          [0.44129997, 0.3724    , 0.2541    , ..., 0.1219    ,
#           0.0853    , 0.0828    ],
#          ...,
#          [0.1374    , 0.1374    , 0.13509999, ..., 0.1361    ,
#           0.1361    , 0.1503    ],
#          [0.1348    , 0.1348    , 0.12879999, ..., 0.183     ,
#           0.183     , 0.2074    ],
#          [0.1258    , 0.1311    , 0.12879999, ..., 0.1681    ,
#           0.2304    , 0.24939999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.68079996, 0.5591    , 0.4838    , ..., 0.1313    ,
#           0.1313    , 0.1339    ],
#          [0.6626    , 0.5006    , 0.4838    , ..., 0.1199    ,
#           0.1199    , 0.1313    ],
#          [0.49449998, 0.4107    , 0.3136    , ..., 0.1078    ,
#           0.069     , 0.0501    ],
#          ...,
#          [0.1434    , 0.1434    , 0.1419    , ..., 0.1504    ,
#           0.1504    , 0.15529999],
#          [0.1299    , 0.1299    , 0.13589999, ..., 0.2113    ,
#           0.2113    , 0.2408    ],
#          [0.1294    , 0.131     , 0.13589999, ..., 0.2408    ,
#           0.22819999, 0.2977    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-07-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5338    , 0.44579998, 0.4456    , ..., 0.12619999,
#           0.12619999, 0.1353    ],
#          [0.5338    , 0.51      , 0.4118    , ..., 0.11319999,
#           0.11319999, 0.0857    ],
#          [0.5251    , 0.4068    , 0.3306    , ..., 0.09999999,
#           0.11319999, 0.0857    ],
#          ...,
#          [0.13669999, 0.13669999, 0.1259    , ..., 0.169     ,
#           0.169     , 0.169     ],
#          [0.1231    , 0.1231    , 0.13669999, ..., 0.2271    ,
#           0.2271    , 0.257     ],
#          [0.12889999, 0.1237    , 0.1383    , ..., 0.2146    ,
#           0.2819    , 0.30359998]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-07-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7158    , 0.5104    , 0.45389998, ..., 0.1266    ,
#           0.1266    , 0.1266    ],
#          [0.682     , 0.43069997, 0.3315    , ..., 0.0902    ,
#           0.0902    , 0.0758    ],
#          [0.49629998, 0.4522    , 0.348     , ..., 0.0806    ,
#           0.0806    , 0.0657    ],
#          ...,
#          [0.1304    , 0.1304    , 0.1266    , ..., 0.1801    ,
#           0.1801    , 0.1801    ],
#          [0.1215    , 0.1215    , 0.1214    , ..., 0.2101    ,
#           0.2101    , 0.2303    ],
#          [0.121     , 0.1188    , 0.1244    , ..., 0.258     ,
#           0.2487    , 0.2742    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-08-13
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6658    , 0.4836    , 0.4836    , ..., 0.1174    ,
#           0.1174    , 0.12329999],
#          [0.6811    , 0.4732    , 0.4732    , ..., 0.1045    ,
#           0.1045    , 0.0795    ],
#          [0.5347    , 0.45769998, 0.2801    , ..., 0.0933    ,
#           0.1045    , 0.0795    ],
#          ...,
#          [0.1237    , 0.1237    , 0.1213    , ..., 0.1655    ,
#           0.1655    , 0.1811    ],
#          [0.12289999, 0.12289999, 0.1149    , ..., 0.2025    ,
#           0.2025    , 0.22109999],
#          [0.1261    , 0.1191    , 0.1243    , ..., 0.22489999,
#           0.25      , 0.2435    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-08-29
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.65639997, 0.48959997, 0.43899998, ..., 0.1266    ,
#           0.1266    , 0.12539999],
#          [0.40309998, 0.4251    , 0.40269998, ..., 0.0929    ,
#           0.0929    , 0.08      ],
#          [0.4904    , 0.4456    , 0.3284    , ..., 0.1014    ,
#           0.0929    , 0.08      ],
#          ...,
#          [0.1398    , 0.1398    , 0.1313    , ..., 0.1221    ,
#           0.1221    , 0.1322    ],
#          [0.1369    , 0.1369    , 0.12879999, ..., 0.1758    ,
#           0.1758    , 0.1639    ],
#          [0.1318    , 0.12619999, 0.12619999, ..., 0.1692    ,
#           0.20459999, 0.2012    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5539    , 0.38099998, 0.406     , ..., 0.1358    ,
#           0.1358    , 0.1435    ],
#          [0.534     , 0.38099998, 0.4258    , ..., 0.1358    ,
#           0.1358    , 0.1358    ],
#          [0.534     , 0.4209    , 0.34039998, ..., 0.1164    ,
#           0.08549999, 0.0621    ],
#          ...,
#          [0.1348    , 0.1348    , 0.1277    , ..., 0.14019999,
#           0.14019999, 0.1384    ],
#          [0.1337    , 0.1337    , 0.1265    , ..., 0.191     ,
#           0.191     , 0.1715    ],
#          [0.1347    , 0.1311    , 0.1291    , ..., 0.1876    ,
#           0.191     , 0.1994    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5125    , 0.509     , 0.4624    , ..., 0.1427    ,
#           0.1427    , 0.1494    ],
#          [0.35169998, 0.2893    , 0.3561    , ..., 0.1335    ,
#           0.1335    , 0.1283    ],
#          [0.4834    , 0.42339998, 0.3067    , ..., 0.1174    ,
#           0.10399999, 0.0828    ],
#          ...,
#          [0.125     , 0.125     , 0.12619999, ..., 0.1503    ,
#           0.1503    , 0.1436    ],
#          [0.125     , 0.125     , 0.1177    , ..., 0.19229999,
#           0.19229999, 0.1673    ],
#          [0.12719999, 0.1235    , 0.11719999, ..., 0.2003    ,
#           0.2699    , 0.2819    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5736    , 0.42819998, 0.4897    , ..., 0.1413    ,
#           0.1413    , 0.14      ],
#          [0.6148    , 0.4454    , 0.3315    , ..., 0.1294    ,
#           0.1294    , 0.1187    ],
#          [0.4651    , 0.3981    , 0.2947    , ..., 0.11589999,
#           0.0986    , 0.0862    ],
#          ...,
#          [0.1353    , 0.1353    , 0.12379999, ..., 0.15969999,
#           0.15969999, 0.1437    ],
#          [0.13149999, 0.13149999, 0.12379999, ..., 0.17809999,
#           0.17809999, 0.18859999],
#          [0.13599999, 0.1285    , 0.12539999, ..., 0.2316    ,
#           0.3107    , 0.1901    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-07-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7418    , 0.5387    , 0.4069    , ..., 0.11719999,
#           0.11719999, 0.14029999],
#          [0.6787    , 0.6971    , 0.45889997, ..., 0.1554    ,
#           0.1554    , 0.1554    ],
#          [0.48569998, 0.3938    , 0.3087    , ..., 0.15689999,
#           0.15699999, 0.1554    ],
#          ...,
#          [0.1286    , 0.1286    , 0.1317    , ..., 0.1603    ,
#           0.1603    , 0.1428    ],
#          [0.1286    , 0.1286    , 0.1215    , ..., 0.1744    ,
#           0.1744    , 0.1987    ],
#          [0.1322    , 0.12379999, 0.12239999, ..., 0.1559    ,
#           0.23619999, 0.3126    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-07-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.79469997, 0.6229    , 0.56159997, ..., 0.1328    ,
#           0.1328    , 0.1221    ],
#          [0.69589996, 0.47689998, 0.4244    , ..., 0.1284    ,
#           0.1284    , 0.08989999],
#          [0.5693    , 0.525     , 0.38639998, ..., 0.11449999,
#           0.0955    , 0.08989999],
#          ...,
#          [0.1413    , 0.1413    , 0.1326    , ..., 0.1471    ,
#           0.1471    , 0.1425    ],
#          [0.134     , 0.134     , 0.1274    , ..., 0.2118    ,
#           0.2118    , 0.1677    ],
#          [0.1387    , 0.12109999, 0.1357    , ..., 0.16399999,
#           0.20529999, 0.2118    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-08-13
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5801    , 0.4915    , 0.5026    , ..., 0.121     ,
#           0.121     , 0.1268    ],
#          [0.4883    , 0.4157    , 0.43719998, ..., 0.1005    ,
#           0.1005    , 0.106     ],
#          [0.5277    , 0.4588    , 0.36519998, ..., 0.094     ,
#           0.094     , 0.0751    ],
#          ...,
#          [0.1237    , 0.1237    , 0.1361    , ..., 0.16399999,
#           0.16399999, 0.1655    ],
#          [0.1383    , 0.1383    , 0.1237    , ..., 0.1766    ,
#           0.1766    , 0.19759999],
#          [0.1511    , 0.1205    , 0.1343    , ..., 0.1713    ,
#           0.197     , 0.2199    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-08-29
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5627    , 0.5151    , 0.3669    , ..., 0.15179999,
#           0.15179999, 0.15439999],
#          [0.6663    , 0.578     , 0.442     , ..., 0.103     ,
#           0.103     , 0.1458    ],
#          [0.5025    , 0.4213    , 0.3593    , ..., 0.1302    ,
#           0.103     , 0.1034    ],
#          ...,
#          [0.13409999, 0.13409999, 0.12199999, ..., 0.1494    ,
#           0.1494    , 0.1389    ],
#          [0.11589999, 0.11589999, 0.11809999, ..., 0.1521    ,
#           0.1521    , 0.1708    ],
#          [0.1266    , 0.1164    , 0.121     , ..., 0.1757    ,
#           0.1766    , 0.19029999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-05-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7094    , 0.5207    , 0.426     , ..., 0.139     ,
#           0.139     , 0.14909999],
#          [0.5731    , 0.7065    , 0.4601    , ..., 0.1032    ,
#           0.1032    , 0.12799999],
#          [0.46109998, 0.428     , 0.3692    , ..., 0.1258    ,
#           0.105     , 0.0658    ],
#          ...,
#          [0.1252    , 0.1252    , 0.1213    , ..., 0.1486    ,
#           0.1486    , 0.14909999],
#          [0.1214    , 0.1214    , 0.1148    , ..., 0.18779999,
#           0.18779999, 0.18779999],
#          [0.11849999, 0.1155    , 0.12539999, ..., 0.167     ,
#           0.183     , 0.18779999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-06-09
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7556    , 0.5141    , 0.3728    , ..., 0.1363    ,
#           0.1363    , 0.1415    ],
#          [0.77129996, 0.6252    , 0.5141    , ..., 0.1363    ,
#           0.1363    , 0.1302    ],
#          [0.57      , 0.39609998, 0.3223    , ..., 0.0894    ,
#           0.0894    , 0.0725    ],
#          ...,
#          [0.12239999, 0.12239999, 0.1171    , ..., 0.1495    ,
#           0.1495    , 0.1347    ],
#          [0.1201    , 0.1201    , 0.1196    , ..., 0.1495    ,
#           0.1495    , 0.15339999],
#          [0.1303    , 0.1193    , 0.1196    , ..., 0.20089999,
#           0.18419999, 0.18789999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-06-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5359    , 0.5359    , 0.48319998, ..., 0.1407    ,
#           0.1407    , 0.1407    ],
#          [0.5767    , 0.5207    , 0.51      , ..., 0.0993    ,
#           0.0993    , 0.1329    ],
#          [0.5427    , 0.4867    , 0.3685    , ..., 0.0917    ,
#           0.0993    , 0.0657    ],
#          ...,
#          [0.1317    , 0.1317    , 0.1226    , ..., 0.1441    ,
#           0.1441    , 0.1495    ],
#          [0.12799999, 0.12799999, 0.1186    , ..., 0.1655    ,
#           0.1655    , 0.1706    ],
#          [0.1259    , 0.123     , 0.1193    , ..., 0.1321    ,
#           0.175     , 0.1995    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-07-11
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5396    , 0.2679    , 0.47559997, ..., 0.1443    ,
#           0.1443    , 0.147     ],
#          [0.5202    , 0.3706    , 0.47559997, ..., 0.1212    ,
#           0.1212    , 0.10179999],
#          [0.5534    , 0.4308    , 0.3554    , ..., 0.09739999,
#           0.09739999, 0.0624    ],
#          ...,
#          [0.12539999, 0.12539999, 0.1188    , ..., 0.15439999,
#           0.15439999, 0.1423    ],
#          [0.12019999, 0.12019999, 0.1168    , ..., 0.1706    ,
#           0.1706    , 0.192     ],
#          [0.1226    , 0.1184    , 0.11629999, ..., 0.1793    ,
#           0.1942    , 0.196     ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-07-27
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.50119996, 0.40019998, 0.50119996, ..., 0.1495    ,
#           0.1495    , 0.12979999],
#          [0.56909996, 0.4368    , 0.4897    , ..., 0.1495    ,
#           0.1495    , 0.12979999],
#          [0.5218    , 0.4789    , 0.4479    , ..., 0.1148    ,
#           0.1148    , 0.062     ],
#          ...,
#          [0.12159999, 0.12159999, 0.1231    , ..., 0.19039999,
#           0.19039999, 0.1778    ],
#          [0.12159999, 0.12159999, 0.12379999, ..., 0.19039999,
#           0.19039999, 0.1968    ],
#          [0.12239999, 0.1173    , 0.12709999, ..., 0.24679999,
#           0.1963    , 0.2548    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-08-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.76199996, 0.5753    , 0.484     , ..., 0.13589999,
#           0.13589999, 0.13589999],
#          [0.76199996, 0.72859997, 0.4888    , ..., 0.13589999,
#           0.13589999, 0.13589999],
#          [0.5166    , 0.473     , 0.38529998, ..., 0.1255    ,
#           0.0914    , 0.0642    ],
#          ...,
#          [0.1174    , 0.1174    , 0.1134    , ..., 0.19409999,
#           0.19409999, 0.1648    ],
#          [0.10749999, 0.10749999, 0.1157    , ..., 0.20349999,
#           0.20349999, 0.2497    ],
#          [0.11369999, 0.11      , 0.11499999, ..., 0.20899999,
#           0.22639999, 0.2688    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-08-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7546    , 0.5334    , 0.4675    , ..., 0.19839999,
#           0.19839999, 0.1857    ],
#          [0.58889997, 0.382     , 0.4084    , ..., 0.11149999,
#           0.11149999, 0.19839999],
#          [0.5276    , 0.4813    , 0.3803    , ..., 0.11149999,
#           0.11149999, 0.11149999],
#          ...,
#          [0.1964    , 0.1964    , 0.184     , ..., 0.1708    ,
#           0.1708    , 0.17289999],
#          [0.17989999, 0.17989999, 0.17989999, ..., 0.1775    ,
#           0.1775    , 0.1951    ],
#          [0.1951    , 0.1822    , 0.20279999, ..., 0.1413    ,
#           0.21519999, 0.2267    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.70059997, 0.475     , 0.4513    , ..., 0.1771    ,
#           0.1771    , 0.19219999],
#          [0.65419996, 0.4326    , 0.389     , ..., 0.1627    ,
#           0.1627    , 0.1627    ],
#          [0.4711    , 0.45319998, 0.40579998, ..., 0.12969999,
#           0.0777    , 0.0777    ],
#          ...,
#          [0.1821    , 0.1821    , 0.17469999, ..., 0.168     ,
#           0.168     , 0.17889999],
#          [0.1812    , 0.1812    , 0.1716    , ..., 0.2007    ,
#           0.2007    , 0.19909999],
#          [0.17809999, 0.17639999, 0.1758    , ..., 0.1621    ,
#           0.21949999, 0.22209999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7994    , 0.69909996, 0.3797    , ..., 0.1777    ,
#           0.1777    , 0.1691    ],
#          [0.6137    , 0.69909996, 0.47309998, ..., 0.121     ,
#           0.121     , 0.1691    ],
#          [0.4836    , 0.42999998, 0.3581    , ..., 0.121     ,
#           0.121     , 0.0884    ],
#          ...,
#          [0.1893    , 0.1893    , 0.1714    , ..., 0.1734    ,
#           0.1734    , 0.1717    ],
#          [0.1841    , 0.1841    , 0.16849999, ..., 0.1953    ,
#           0.1953    , 0.2182    ],
#          [0.1832    , 0.17189999, 0.1917    , ..., 0.1598    ,
#           0.24859999, 0.27899998]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6583    , 0.4775    , 0.4193    , ..., 0.1663    ,
#           0.1663    , 0.18339999],
#          [0.6178    , 0.4091    , 0.4283    , ..., 0.17459999,
#           0.17459999, 0.1511    ],
#          [0.4464    , 0.4464    , 0.4148    , ..., 0.134     ,
#           0.0997    , 0.0768    ],
#          ...,
#          [0.1855    , 0.1855    , 0.1681    , ..., 0.167     ,
#           0.167     , 0.1672    ],
#          [0.1637    , 0.1637    , 0.1637    , ..., 0.18329999,
#           0.18329999, 0.1953    ],
#          [0.1838    , 0.1714    , 0.1871    , ..., 0.1856    ,
#           0.2418    , 0.2395    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-07-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.3741    , 0.4139    , 0.4937    , ..., 0.1732    ,
#           0.1732    , 0.1783    ],
#          [0.5009    , 0.44149998, 0.4353    , ..., 0.1716    ,
#           0.1716    , 0.17019999],
#          [0.5403    , 0.5204    , 0.4711    , ..., 0.1427    ,
#           0.10219999, 0.0557    ],
#          ...,
#          [0.1935    , 0.1935    , 0.1674    , ..., 0.1591    ,
#           0.1591    , 0.1706    ],
#          [0.168     , 0.168     , 0.1801    , ..., 0.213     ,
#           0.213     , 0.213     ],
#          [0.185     , 0.17029999, 0.1892    , ..., 0.1823    ,
#           0.2757    , 0.2677    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-07-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.2525    , 0.3743    , 0.38529998, ..., 0.14919999,
#           0.14919999, 0.1503    ],
#          [0.4154    , 0.35259998, 0.43919998, ..., 0.14919999,
#           0.14919999, 0.1503    ],
#          [0.5441    , 0.40179998, 0.40179998, ..., 0.11759999,
#           0.11759999, 0.0646    ],
#          ...,
#          [0.17999999, 0.17999999, 0.1678    , ..., 0.2058    ,
#           0.2058    , 0.1977    ],
#          [0.16679999, 0.16679999, 0.1591    , ..., 0.287     ,
#           0.287     , 0.2993    ],
#          [0.174     , 0.1616    , 0.1616    , ..., 0.2841    ,
#           0.43159997, 0.2941    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-08-13
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.22659999, 0.32619998, 0.5469    , ..., 0.15619999,
#           0.15619999, 0.166     ],
#          [0.3355    , 0.3197    , 0.5469    , ..., 0.1444    ,
#           0.1444    , 0.1393    ],
#          [0.5521    , 0.4202    , 0.41889998, ..., 0.13599999,
#           0.11009999, 0.078     ],
#          ...,
#          [0.1777    , 0.1777    , 0.1645    , ..., 0.1889    ,
#           0.1889    , 0.1933    ],
#          [0.1656    , 0.1656    , 0.16569999, ..., 0.22309999,
#           0.22309999, 0.2324    ],
#          [0.17809999, 0.17809999, 0.16939999, ..., 0.32729998,
#           0.22309999, 0.2825    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-08-29
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7546    , 0.5198    , 0.4123    , ..., 0.1434    ,
#           0.1434    , 0.1538    ],
#          [0.7635    , 0.6088    , 0.281     , ..., 0.1352    ,
#           0.1352    , 0.1352    ],
#          [0.5133    , 0.47959998, 0.3593    , ..., 0.1355    ,
#           0.0883    , 0.0851    ],
#          ...,
#          [0.1584    , 0.1584    , 0.1512    , ..., 0.15879999,
#           0.15879999, 0.1549    ],
#          [0.1538    , 0.1538    , 0.1445    , ..., 0.1806    ,
#           0.1806    , 0.20529999],
#          [0.156     , 0.14389999, 0.1599    , ..., 0.1599    ,
#           0.232     , 0.25669998]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7349    , 0.47289997, 0.3854    , ..., 0.1369    ,
#           0.1369    , 0.1567    ],
#          [0.7349    , 0.47869998, 0.47869998, ..., 0.1356    ,
#           0.1356    , 0.1143    ],
#          [0.5085    , 0.3302    , 0.3137    , ..., 0.1237    ,
#           0.0718    , 0.0718    ],
#          ...,
#          [0.15959999, 0.15959999, 0.1582    , ..., 0.1635    ,
#           0.1635    , 0.1619    ],
#          [0.153     , 0.153     , 0.1619    , ..., 0.22819999,
#           0.22819999, 0.1899    ],
#          [0.1576    , 0.1522    , 0.1619    , ..., 0.204     ,
#           0.2366    , 0.241     ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.76909995, 0.5707    , 0.4545    , ..., 0.1454    ,
#           0.1454    , 0.15339999],
#          [0.775     , 0.5916    , 0.30699998, ..., 0.0903    ,
#           0.0903    , 0.1454    ],
#          [0.5046    , 0.4369    , 0.3175    , ..., 0.1525    ,
#           0.0903    , 0.0762    ],
#          ...,
#          [0.16319999, 0.16319999, 0.16319999, ..., 0.1504    ,
#           0.1504    , 0.1585    ],
#          [0.1574    , 0.1574    , 0.1674    , ..., 0.18699999,
#           0.18699999, 0.1908    ],
#          [0.1593    , 0.1593    , 0.1689    , ..., 0.18429999,
#           0.2498    , 0.25059998]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.4112    , 0.39999998, 0.42209998, ..., 0.1364    ,
#           0.1364    , 0.12289999],
#          [0.4112    , 0.3199    , 0.3199    , ..., 0.1364    ,
#           0.1364    , 0.12289999],
#          [0.45859998, 0.4068    , 0.3531    , ..., 0.1127    ,
#           0.1127    , 0.0617    ],
#          ...,
#          [0.1595    , 0.1595    , 0.1593    , ..., 0.16149999,
#           0.16149999, 0.1725    ],
#          [0.1651    , 0.1651    , 0.1651    , ..., 0.20359999,
#           0.20359999, 0.17019999],
#          [0.16219999, 0.16839999, 0.16839999, ..., 0.2193    ,
#           0.20359999, 0.2445    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-07-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6993    , 0.6993    , 0.4852    , ..., 0.1378    ,
#           0.1378    , 0.1326    ],
#          [0.7704    , 0.5191    , 0.28329998, ..., 0.1378    ,
#           0.1378    , 0.1326    ],
#          [0.5215    , 0.454     , 0.4393    , ..., 0.1347    ,
#           0.1347    , 0.0613    ],
#          ...,
#          [0.153     , 0.153     , 0.14479999, ..., 0.1889    ,
#           0.1889    , 0.1884    ],
#          [0.1413    , 0.1413    , 0.1407    , ..., 0.24749999,
#           0.24749999, 0.30789998],
#          [0.1502    , 0.1371    , 0.1413    , ..., 0.2652    ,
#           0.2915    , 0.30949998]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-07-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5566    , 0.4694    , 0.3656    , ..., 0.1573    ,
#           0.1573    , 0.13499999],
#          [0.5566    , 0.3712    , 0.3358    , ..., 0.1041    ,
#           0.1041    , 0.0792    ],
#          [0.51699996, 0.41149998, 0.3974    , ..., 0.1413    ,
#           0.08549999, 0.0879    ],
#          ...,
#          [0.16499999, 0.16499999, 0.1496    , ..., 0.1982    ,
#           0.1982    , 0.2065    ],
#          [0.14389999, 0.14389999, 0.1558    , ..., 0.26479998,
#           0.26479998, 0.234     ],
#          [0.1681    , 0.1554    , 0.1566    , ..., 0.2703    ,
#           0.2914    , 0.3123    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-08-13
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7175    , 0.5129    , 0.5203    , ..., 0.1423    ,
#           0.1423    , 0.1388    ],
#          [0.78069997, 0.6319    , 0.4964    , ..., 0.0989    ,
#           0.0989    , 0.1382    ],
#          [0.59139997, 0.4675    , 0.4414    , ..., 0.1116    ,
#           0.1116    , 0.0554    ],
#          ...,
#          [0.161     , 0.161     , 0.1591    , ..., 0.2076    ,
#           0.2076    , 0.2075    ],
#          [0.15789999, 0.15789999, 0.1732    , ..., 0.29299998,
#           0.29299998, 0.2739    ],
#          [0.2103    , 0.1858    , 0.1732    , ..., 0.2735    ,
#           0.27879998, 0.2953    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-08-29
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.65389997, 0.5708    , 0.3665    , ..., 0.118     ,
#           0.118     , 0.1282    ],
#          [0.5295    , 0.4105    , 0.3665    , ..., 0.1083    ,
#           0.1083    , 0.0955    ],
#          [0.52279997, 0.4105    , 0.3051    , ..., 0.1227    ,
#           0.0562    , 0.0836    ],
#          ...,
#          [0.1241    , 0.1241    , 0.1212    , ..., 0.1582    ,
#           0.1582    , 0.1524    ],
#          [0.11979999, 0.11979999, 0.1164    , ..., 0.168     ,
#           0.168     , 0.2144    ],
#          [0.12249999, 0.1199    , 0.1283    , ..., 0.1753    ,
#           0.2252    , 0.1907    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2007-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.815     , 0.5683    , 0.4125    , ..., 0.1251    ,
#           0.1251    , 0.1251    ],
#          [0.603     , 0.5683    , 0.31509998, ..., 0.1155    ,
#           0.1155    , 0.1096    ],
#          [0.603     , 0.39929998, 0.33249998, ..., 0.09      ,
#           0.09      , 0.0576    ],
#          ...,
#          [0.1301    , 0.1301    , 0.118     , ..., 0.15179999,
#           0.15179999, 0.15349999],
#          [0.1164    , 0.1164    , 0.125     , ..., 0.2395    ,
#           0.2395    , 0.1759    ],
#          [0.1302    , 0.11849999, 0.1257    , ..., 0.2008    ,
#           0.20719999, 0.24749999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2007-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5614    , 0.5288    , 0.3849    , ..., 0.1187    ,
#           0.1187    , 0.1264    ],
#          [0.333     , 0.3463    , 0.2505    , ..., 0.0837    ,
#           0.0837    , 0.12459999],
#          [0.45389998, 0.41099998, 0.32299998, ..., 0.1223    ,
#           0.0837    , 0.0837    ],
#          ...,
#          [0.1222    , 0.1222    , 0.1235    , ..., 0.1485    ,
#           0.1485    , 0.1537    ],
#          [0.1162    , 0.1162    , 0.1217    , ..., 0.1742    ,
#           0.1742    , 0.20789999],
#          [0.1301    , 0.11979999, 0.12289999, ..., 0.2135    ,
#           0.2135    , 0.2461    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2007-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.74829996, 0.49879998, 0.45      , ..., 0.1248    ,
#           0.1248    , 0.1248    ],
#          [0.6773    , 0.49879998, 0.3511    , ..., 0.0994    ,
#           0.0994    , 0.0777    ],
#          [0.5432    , 0.44419998, 0.3775    , ..., 0.0958    ,
#           0.0994    , 0.0777    ],
#          ...,
# ...
#    * date         (date) datetime64[ns] 8B 2020-08-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.21519999, 0.27629998, 0.5169    , ..., 0.1713    ,
#           0.1713    , 0.1697    ],
#          [0.2121    , 0.3031    , 0.4021    , ..., 0.1554    ,
#           0.1554    , 0.1219    ],
#          [0.26729998, 0.3408    , 0.4626    , ..., 0.1554    ,
#           0.1554    , 0.1219    ],
#          ...,
#          [0.1488    , 0.1488    , 0.1425    , ..., 0.1669    ,
#           0.1669    , 0.1788    ],
#          [0.1422    , 0.1422    , 0.14819999, ..., 0.2214    ,
#           0.2214    , 0.2286    ],
#          [0.1487    , 0.1416    , 0.1519    , ..., 0.17189999,
#           0.2261    , 0.2056    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-08-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5712    , 0.51879996, 0.4226    , ..., 0.1442    ,
#           0.1442    , 0.1563    ],
#          [0.5669    , 0.46269998, 0.3324    , ..., 0.1236    ,
#           0.1236    , 0.1563    ],
#          [0.389     , 0.3391    , 0.4062    , ..., 0.11499999,
#           0.1334    , 0.1236    ],
#          ...,
#          [0.11759999, 0.11759999, 0.1169    , ..., 0.1451    ,
#           0.1451    , 0.1586    ],
#          [0.1158    , 0.1158    , 0.1166    , ..., 0.2218    ,
#           0.2218    , 0.17889999],
#          [0.1183    , 0.11539999, 0.1166    , ..., 0.1733    ,
#           0.2021    , 0.17889999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7349    , 0.5966    , 0.38709998, ..., 0.14209999,
#           0.14209999, 0.1431    ],
#          [0.4064    , 0.4261    , 0.3412    , ..., 0.144     ,
#           0.144     , 0.1215    ],
#          [0.2564    , 0.36679998, 0.4111    , ..., 0.1416    ,
#           0.09559999, 0.0795    ],
#          ...,
#          [0.12419999, 0.12419999, 0.125     , ..., 0.1555    ,
#           0.1555    , 0.16239999],
#          [0.1209    , 0.1209    , 0.1264    , ..., 0.2004    ,
#           0.2004    , 0.1743    ],
#          [0.1269    , 0.1209    , 0.1264    , ..., 0.1749    ,
#           0.19309999, 0.1963    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6476    , 0.5002    , 0.4511    , ..., 0.1413    ,
#           0.1413    , 0.1457    ],
#          [0.43109998, 0.3297    , 0.41279998, ..., 0.14039999,
#           0.14039999, 0.1418    ],
#          [0.39119998, 0.40989998, 0.33519998, ..., 0.1545    ,
#           0.0976    , 0.0695    ],
#          ...,
#          [0.13499999, 0.13499999, 0.1318    , ..., 0.14999999,
#           0.14999999, 0.15269999],
#          [0.1308    , 0.1308    , 0.1313    , ..., 0.16679999,
#           0.16679999, 0.20089999],
#          [0.1366    , 0.13      , 0.13      , ..., 0.1498    ,
#           0.2174    , 0.18879999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5255    , 0.5255    , 0.32009998, ..., 0.1687    ,
#           0.1687    , 0.16399999],
#          [0.6541    , 0.5009    , 0.27699998, ..., 0.154     ,
#           0.154     , 0.1545    ],
#          [0.3576    , 0.4396    , 0.3066    , ..., 0.147     ,
#           0.147     , 0.1063    ],
#          ...,
#          [0.12459999, 0.12459999, 0.1257    , ..., 0.14819999,
#           0.14819999, 0.1501    ],
#          [0.12019999, 0.12019999, 0.1257    , ..., 0.17019999,
#           0.17019999, 0.1971    ],
#          [0.1415    , 0.12529999, 0.1257    , ..., 0.1168    ,
#           0.1918    , 0.19049999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-07-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6462    , 0.41939998, 0.4348    , ..., 0.1644    ,
#           0.1644    , 0.1644    ],
#          [0.6234    , 0.6234    , 0.3612    , ..., 0.1419    ,
#           0.1419    , 0.1419    ],
#          [0.38189998, 0.38189998, 0.47439998, ..., 0.12469999,
#           0.1419    , 0.1419    ],
#          ...,
#          [0.1408    , 0.1408    , 0.13939999, ..., 0.16839999,
#           0.16839999, 0.1628    ],
#          [0.1221    , 0.1221    , 0.1378    , ..., 0.21499999,
#           0.21499999, 0.2074    ],
#          [0.1466    , 0.1313    , 0.1378    , ..., 0.1475    ,
#           0.2164    , 0.1794    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-07-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.64739996, 0.5958    , 0.4847    , ..., 0.2653    ,
#           0.2653    , 0.2653    ],
#          [0.2962    , 0.5958    , 0.3576    , ..., 0.28919998,
#           0.28919998, 0.2374    ],
#          [0.2962    , 0.3504    , 0.4606    , ..., 0.1716    ,
#           0.1716    , 0.1414    ],
#          ...,
#          [0.1735    , 0.1735    , 0.163     , ..., 0.2269    ,
#           0.2269    , 0.23269999],
#          [0.16929999, 0.16929999, 0.1521    , ..., 0.27089998,
#           0.27089998, 0.3163    ],
#          [0.17719999, 0.1653    , 0.1513    , ..., 0.21159999,
#           0.2897    , 0.2455    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-08-13
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6486    , 0.6261    , 0.4323    , ..., 0.2737    ,
#           0.2737    , 0.2873    ],
#          [0.5444    , 0.6611    , 0.3971    , ..., 0.2737    ,
#           0.2737    , 0.2873    ],
#          [0.29709998, 0.42319998, 0.49809998, ..., 0.2075    ,
#           0.2043    , 0.10789999],
#          ...,
#          [0.1809    , 0.1809    , 0.155     , ..., 0.18789999,
#           0.18789999, 0.2074    ],
#          [0.1546    , 0.1546    , 0.1723    , ..., 0.2305    ,
#           0.2305    , 0.2523    ],
#          [0.20719999, 0.1768    , 0.18079999, ..., 0.17379999,
#           0.225     , 0.2428    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-08-29
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5154    , 0.3202    , 0.3663    , ..., 0.1363    ,
#           0.1363    , 0.15869999],
#          [0.3304    , 0.29029998, 0.3202    , ..., 0.15609999,
#           0.15609999, 0.15609999],
#          [0.3159    , 0.36749998, 0.31129998, ..., 0.1379    ,
#           0.0788    , 0.0896    ],
#          ...,
#          [0.1155    , 0.1155    , 0.1146    , ..., 0.1476    ,
#           0.1476    , 0.1577    ],
#          [0.1124    , 0.1124    , 0.1114    , ..., 0.2198    ,
#           0.2198    , 0.17819999],
#          [0.1286    , 0.1122    , 0.1193    , ..., 0.1856    ,
#           0.1853    , 0.2198    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-05-25
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7495    , 0.513     , 0.4314    , ..., 0.1542    ,
#           0.1542    , 0.15789999],
#          [0.7495    , 0.58489996, 0.3401    , ..., 0.1551    ,
#           0.1551    , 0.1551    ],
#          [0.294     , 0.3554    , 0.4272    , ..., 0.13149999,
#           0.0946    , 0.11099999],
#          ...,
#          [0.1227    , 0.1227    , 0.114     , ..., 0.1488    ,
#           0.1488    , 0.1554    ],
#          [0.1158    , 0.1158    , 0.12      , ..., 0.1488    ,
#           0.1488    , 0.22549999],
#          [0.1244    , 0.1186    , 0.12019999, ..., 0.1591    ,
#           0.20359999, 0.1848    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-06-10
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6242    , 0.55009997, 0.4283    , ..., 0.1548    ,
#           0.1548    , 0.1616    ],
#          [0.5875    , 0.4651    , 0.3304    , ..., 0.11669999,
#           0.11669999, 0.11669999],
#          [0.3331    , 0.38169998, 0.464     , ..., 0.13849999,
#           0.11669999, 0.11669999],
#          ...,
#          [0.12889999, 0.12889999, 0.1169    , ..., 0.1437    ,
#           0.1437    , 0.1591    ],
#          [0.1151    , 0.1151    , 0.1168    , ..., 0.1437    ,
#           0.1437    , 0.2417    ],
#          [0.1303    , 0.1151    , 0.11979999, ..., 0.1872    ,
#           0.18259999, 0.2513    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-06-26
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.7155    , 0.53929996, 0.4524    , ..., 0.18679999,
#           0.18679999, 0.18679999],
#          [0.5437    , 0.5437    , 0.3565    , ..., 0.18679999,
#           0.18679999, 0.18679999],
#          [0.3919    , 0.3919    , 0.4236    , ..., 0.1322    ,
#           0.1322    , 0.10219999],
#          ...,
#          [0.1363    , 0.1363    , 0.1361    , ..., 0.1449    ,
#           0.1449    , 0.1604    ],
#          [0.1098    , 0.1098    , 0.1098    , ..., 0.2087    ,
#           0.2087    , 0.23179999],
#          [0.1276    , 0.1169    , 0.1204    , ..., 0.1634    ,
#           0.19309999, 0.182     ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-07-12
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.6976    , 0.543     , 0.46859998, ..., 0.19489999,
#           0.19489999, 0.19489999],
#          [0.5051    , 0.38149998, 0.5058    , ..., 0.1345    ,
#           0.1345    , 0.19489999],
#          [0.4339    , 0.38149998, 0.3626    , ..., 0.1345    ,
#           0.1345    , 0.1345    ],
#          ...,
#          [0.1215    , 0.1215    , 0.1133    , ..., 0.1546    ,
#           0.1546    , 0.1628    ],
#          [0.11629999, 0.11629999, 0.1114    , ..., 0.20629999,
#           0.20629999, 0.23719999],
#          [0.1166    , 0.1107    , 0.1109    , ..., 0.1884    ,
#           0.1937    , 0.23719999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-07-28
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.3886    , 0.35369998, 0.3416    , ..., 0.1927    ,
#           0.1927    , 0.15969999],
#          [0.3795    , 0.3638    , 0.30359998, ..., 0.14909999,
#           0.14909999, 0.1285    ],
#          [0.28129998, 0.3478    , 0.4445    , ..., 0.1157    ,
#           0.1157    , 0.0738    ],
#          ...,
#          [0.1303    , 0.1303    , 0.1303    , ..., 0.1739    ,
#           0.1739    , 0.1859    ],
#          [0.13319999, 0.13319999, 0.1303    , ..., 0.19399999,
#           0.19399999, 0.2383    ],
#          [0.1662    , 0.13319999, 0.1348    , ..., 0.17289999,
#           0.2034    , 0.23249999]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-08-13
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 382)> Size: 310kB
#  array([[[0.5902    , 0.3793    , 0.3145    , ..., 0.15359999,
#           0.15359999, 0.1564    ],
#          [0.6694    , 0.4878    , 0.32909998, ..., 0.159     ,
#           0.159     , 0.1331    ],
#          [0.3103    , 0.39409998, 0.4527    , ..., 0.154     ,
#           0.1026    , 0.0448    ],
#          ...,
#          [0.1338    , 0.1338    , 0.1192    , ..., 0.174     ,
#           0.174     , 0.163     ],
#          [0.12889999, 0.12889999, 0.1205    , ..., 0.2146    ,
#           0.2146    , 0.2025    ],
#          [0.13069999, 0.1157    , 0.12629999, ..., 0.17359999,
#           0.2146    , 0.2085    ]]], shape=(1, 203, 382), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-08-29
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area]

# %% [markdown]
# ## Combine Rasters
#
# Next, stack your arrays by date into a time series using the
# `xr.combine_by_coords()` function. You will have to tell it which
# dimension you want to stack your data in.

# %%
# Combine NDVI images from all dates
ndvi_da = xr.combine_by_coords(ndvi_das).NDVI
ndvi_da.plot.hist()

# %%
ndvi_da
# Out:
# <xarray.DataArray 'NDVI' (date: 154, y: 203, x: 382)> Size: 48MB
# array([[[0.8282    , 0.6146    , 0.3796    , ..., 0.1542    ,
#          0.1542    , 0.1774    ],
#         [0.52349997, 0.32029998, 0.46359998, ..., 0.145     ,
#          0.145     , 0.145     ],
#         [0.52349997, 0.38509998, 0.4567    , ..., 0.0962    ,
#          0.058     , 0.0641    ],
#         ...,
#         [0.13759999, 0.13759999, 0.1283    , ..., 0.1489    ,
#          0.1489    , 0.1568    ],
#         [0.1299    , 0.1299    , 0.12379999, ..., 0.1831    ,
#          0.1831    , 0.23169999],
#         [0.1347    , 0.1309    , 0.1329    , ..., 0.15709999,
#          0.2384    , 0.2452    ]],
#
#        [[0.5146    , 0.42249998, 0.3706    , ..., 0.1656    ,
#          0.1656    , 0.1656    ],
#         [0.3543    , 0.4138    , 0.3706    , ..., 0.1275    ,
#          0.1275    , 0.0968    ],
#         [0.48029998, 0.3543    , 0.3687    , ..., 0.075     ,
#          0.075     , 0.0968    ],
# ...
#         [0.1303    , 0.1303    , 0.1303    , ..., 0.1739    ,
#          0.1739    , 0.1859    ],
#         [0.13319999, 0.13319999, 0.1303    , ..., 0.19399999,
#          0.19399999, 0.2383    ],
#         [0.1662    , 0.13319999, 0.1348    , ..., 0.17289999,
#          0.2034    , 0.23249999]],
#
#        [[0.5902    , 0.3793    , 0.3145    , ..., 0.15359999,
#          0.15359999, 0.1564    ],
#         [0.6694    , 0.4878    , 0.32909998, ..., 0.159     ,
#          0.159     , 0.1331    ],
#         [0.3103    , 0.39409998, 0.4527    , ..., 0.154     ,
#          0.1026    , 0.0448    ],
#         ...,
#         [0.1338    , 0.1338    , 0.1192    , ..., 0.174     ,
#          0.174     , 0.163     ],
#         [0.12889999, 0.12889999, 0.1205    , ..., 0.2146    ,
#          0.2146    , 0.2025    ],
#         [0.13069999, 0.1157    , 0.12629999, ..., 0.17359999,
#          0.2146    , 0.2085    ]]], shape=(154, 203, 382), dtype=float32)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#   * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#     spatial_ref  int64 8B 0
#   * date         (date) datetime64[ns] 1kB 2001-05-25 2001-06-10 ... 2022-08-29
# Attributes:
#     units:          NDVI
#     AREA_OR_POINT:  Area

# %% [markdown]
# # STEP -1: Wrap up
#
# Don’t forget to store your variables so you can use them in other
# notebooks! Replace `var1` and `var2` with the variable you want to save,
# separated by spaces.

# %%
# %store ndvi_da

# %% [markdown]
# Finally, be sure to `Restart` and `Run all` to make sure your notebook
# works all the way through!
